# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
v = 60
v_ms = v*(5/18)
d = 500
h = 10
t = np.linspace(0,100,7000)
c = 3e8

theta = np.arctan(10/(500-v*t))
base = (500-v*t)
hyp = np.sqrt(base**2 +  h**2)
cosine = base/hyp

# %%
Fc = 900e6
Fd = Fc*(v_ms/c)*cosine

# %%
plt.plot(t, Fd)
plt.show()

# %%
abs_theta
# Out:
# [0.019997333973150535,
#  0.02003166972147523,
#  0.02006612356682744,
#  0.02010069611946262,
#  0.020135387993847526,
#  0.020170199808696544,
#  0.020205132187008486,
#  0.02024018575610373,
#  0.020275361147661732,
#  0.020310658997758985,
#  0.02034607994690731,
#  0.020381624640092577,
#  0.02041729372681386,
#  0.02045308786112294,
#  0.020489007701664282,
#  0.020525053911715423,
#  0.020561227159227747,
#  0.020597528116867728,
#  0.02063395746205863,
#  0.020670515877022577,
#  0.020707204048823157,
#  0.020744022669408425,
#  0.02078097243565436,
#  0.020818054049408837,
#  0.020855268217536038,
#  0.020892615651961304,
#  0.020930097069716557,
#  0.020967713192986133,
#  0.021005464749153144,
#  0.021043352470846332,
#  0.021081377095987452,
#  0.021119539367839123,
#  0.021157840035053256,
#  0.021196279851719967,
#  0.021234859577417033,
#  0.02127357997725991,
#  0.021312441821952268,
#  0.02135144588783711,
#  0.021390592956948423,
#  0.021429883817063417,
# ...
